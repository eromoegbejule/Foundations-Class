# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %%
import requests

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
url = "http://api.weatherapi.com/v1/current.json?key=ea62b294238944a09bd05542200411&q=Lagos"

# %%
response = requests.get('http://api.weatherapi.com/v1/current.json?key=ea62b294238944a09bd05542200411&q=Lagos')
data = response.json()

# %%
print (data)
# Out:
# {'location': {'name': 'Lagos', 'region': 'Lagos', 'country': 'Nigeria', 'lat': 6.45, 'lon': 3.4, 'tz_id': 'Africa/Lagos', 'localtime_epoch': 1604793628, 'localtime': '2020-11-08 1:00'}, 'current': {'last_updated_epoch': 1604792709, 'last_updated': '2020-11-08 00:45', 'temp_c': 27.0, 'temp_f': 80.6, 'is_day': 0, 'condition': {'text': 'Patchy light rain with thunder', 'icon': '//cdn.weatherapi.com/weather/64x64/night/386.png', 'code': 1273}, 'wind_mph': 0.0, 'wind_kph': 0.0, 'wind_degree': 0, 'wind_dir': 'N', 'pressure_mb': 1015.0, 'pressure_in': 30.4, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 89, 'cloud': 25, 'feelslike_c': 29.9, 'feelslike_f': 85.8, 'vis_km': 8.0, 'vis_miles': 4.0, 'uv': 1.0, 'gust_mph': 13.4, 'gust_kph': 21.6}}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data['current']
# Out:
# {'last_updated_epoch': 1604792709,
#  'last_updated': '2020-11-08 00:45',
#  'temp_c': 27.0,
#  'temp_f': 80.6,
#  'is_day': 0,
#  'condition': {'text': 'Patchy light rain with thunder',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/386.png',
#   'code': 1273},
#  'wind_mph': 0.0,
#  'wind_kph': 0.0,
#  'wind_degree': 0,
#  'wind_dir': 'N',
#  'pressure_mb': 1015.0,
#  'pressure_in': 30.4,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 89,
#  'cloud': 25,
#  'feelslike_c': 29.9,
#  'feelslike_f': 85.8,
#  'vis_km': 8.0,
#  'vis_miles': 4.0,
#  'uv': 1.0,
#  'gust_mph': 13.4,
#  'gust_kph': 21.6}

# %%
print("The wind speed is," wind-mph "but it feels warmer by:" humidity)
# Out:
#   File "<ipython-input-30-f4d9b200a568>", line 1
#     print("The wind speed is," wind-mph "but it feels warmer by:" humidity)
#                                ^
# SyntaxError: invalid syntax

# %%
#Difference in warmth

# %%
# UNFINISHEDDDD

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible on next Thursday?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %%
#Endpoint for today is below:

# %%
url = "http://api.weatherapi.com/v1/astronomy.json?key=ea62b294238944a09bd05542200411&q=Lagos&dt=2020-11-07"

# %%
astronomy = requests.get('http://api.weatherapi.com/v1/astronomy.json?key=ea62b294238944a09bd05542200411&q=Lagos&dt=2020-11-07')
data = astronomy.json()

# %%
print(astronomy.json())
# Out:
# {'location': {'name': 'Lagos', 'region': 'Lagos', 'country': 'Nigeria', 'lat': 6.45, 'lon': 3.4, 'tz_id': 'Africa/Lagos', 'localtime_epoch': 1604796621, 'localtime': '2020-11-08 1:50'}, 'astronomy': {'astro': {'sunrise': '06:34 AM', 'sunset': '06:26 PM', 'moonrise': 'No moonrise', 'moonset': '12:09 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '43'}}}

# %%
#Endpoint for next Thursday, November 9 (since we have no money to pay for license for November 12) is below:

# %%
url = "http://api.weatherapi.com/v1/astronomy.json?key=ea62b294238944a09bd05542200411&q=Lagos&dt=2020-11-09"

# %%
moon_illumination = requests.get('http://api.weatherapi.com/v1/astronomy.json?key=ea62b294238944a09bd05542200411&q=Lagos&dt=2020-11-09')
free_limit = moon_illumination.json()
print(moon_illumination.json())
# Out:
# {'location': {'name': 'Lagos', 'region': 'Lagos', 'country': 'Nigeria', 'lat': 6.45, 'lon': 3.4, 'tz_id': 'Africa/Lagos', 'localtime_epoch': 1604797639, 'localtime': '2020-11-08 2:07'}, 'astronomy': {'astro': {'sunrise': '06:34 AM', 'sunset': '06:26 PM', 'moonrise': '01:09 AM', 'moonset': '01:51 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '28'}}}

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
#Pulling data from Forecast
url = "http://api.weatherapi.com/v1/forecast.json?key=ea62b294238944a09bd05542200411&q=Lagos&days=1"

# %%
#Present difference between both sets of temperatures
temp_diff = requests.get('http://api.weatherapi.com/v1/forecast.json?key=ea62b294238944a09bd05542200411&q=Lagos&days=1')
temp = temp_diff.json()

# %%
print(temp_diff.json())
# Out:
# {'location': {'name': 'Lagos', 'region': 'Lagos', 'country': 'Nigeria', 'lat': 6.45, 'lon': 3.4, 'tz_id': 'Africa/Lagos', 'localtime_epoch': 1604801372, 'localtime': '2020-11-08 3:09'}, 'current': {'last_updated_epoch': 1604799910, 'last_updated': '2020-11-08 02:45', 'temp_c': 26.0, 'temp_f': 78.8, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 0.0, 'wind_kph': 0.0, 'wind_degree': 0, 'wind_dir': 'N', 'pressure_mb': 1014.0, 'pressure_in': 30.4, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 94, 'cloud': 25, 'feelslike_c': 28.3, 'feelslike_f': 82.9, 'vis_km': 8.0, 'vis_miles': 4.0, 'uv': 1.0, 'gust_mph': 13.4, 'gust_kph': 21.6}, 'forecast': {'forecastday': [{'date': '2020-11-08', 'date_epoch': 1604793600, 'day': {'maxtemp_c': 30.4, 'maxtemp_f': 86.7, 'mintemp_c': 26.8, 'mintemp_f': 80.2, 'avgtemp_c': 28.5, 'avgtemp_f': 83.3, 'maxwind_mph': 9.4, 'maxwind_kph': 15.1, 'totalprecip_mm': 10.5, 'totalprecip_in': 0.41, 'avgvis_km': 9.1, 'avgvis_miles': 5.0, 'avghumidity': 72.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '88', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 8.0}, 'astro': {'sunrise': '06:35 AM', 'sunset': '06:26 PM', 'moonrise': '12:14 AM', 'moonset': '01:01 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': '41'}, 'hour': [{'time_epoch': 1604790000, 'time': '2020-11-08 00:00', 'temp_c': 27.8, 'temp_f': 82.0, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 9.2, 'wind_kph': 14.8, 'wind_degree': 218, 'wind_dir': 'SW', 'pressure_mb': 1013.0, 'pressure_in': 30.4, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 77, 'cloud': 36, 'feelslike_c': 31.3, 'feelslike_f': 88.3, 'windchill_c': 27.8, 'windchill_f': 82.0, 'heatindex_c': 31.3, 'heatindex_f': 88.3, 'dewpoint_c': 23.3, 'dewpoint_f': 73.9, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 13.4, 'gust_kph': 21.6}, {'time_epoch': 1604793600, 'time': '2020-11-08 01:00', 'temp_c': 27.6, 'temp_f': 81.7, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 8.5, 'wind_kph': 13.7, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1013.0, 'pressure_in': 30.4, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 78, 'cloud': 46, 'feelslike_c': 31.1, 'feelslike_f': 88.0, 'windchill_c': 27.6, 'windchill_f': 81.7, 'heatindex_c': 31.1, 'heatindex_f': 88.0, 'dewpoint_c': 23.4, 'dewpoint_f': 74.1, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 12.3, 'gust_kph': 19.8}, {'time_epoch': 1604797200, 'time': '2020-11-08 02:00', 'temp_c': 27.5, 'temp_f': 81.5, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 8.3, 'wind_kph': 13.3, 'wind_degree': 228, 'wind_dir': 'SW', 'pressure_mb': 1013.0, 'pressure_in': 30.4, 'precip_mm': 0.3, 'precip_in': 0.01, 'humidity': 78, 'cloud': 59, 'feelslike_c': 30.9, 'feelslike_f': 87.6, 'windchill_c': 27.5, 'windchill_f': 81.5, 'heatindex_c': 30.9, 'heatindex_f': 87.6, 'dewpoint_c': 23.3, 'dewpoint_f': 73.9, 'will_it_rain': 0, 'chance_of_rain': '24', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 9.7, 'vis_miles': 6.0, 'gust_mph': 11.9, 'gust_kph': 19.1}, {'time_epoch': 1604800800, 'time': '2020-11-08 03:00', 'temp_c': 27.4, 'temp_f': 81.3, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 237, 'wind_dir': 'WSW', 'pressure_mb': 1012.0, 'pressure_in': 30.4, 'precip_mm': 0.5, 'precip_i ...

# %%
temp.keys()
# Out:
# dict_keys(['location', 'current', 'forecast', 'alert'])

# %%
temp['forecast']
# Out:
# {'forecastday': [{'date': '2020-11-08',
#    'date_epoch': 1604793600,
#    'day': {'maxtemp_c': 30.4,
#     'maxtemp_f': 86.7,
#     'mintemp_c': 26.8,
#     'mintemp_f': 80.2,
#     'avgtemp_c': 28.5,
#     'avgtemp_f': 83.3,
#     'maxwind_mph': 9.4,
#     'maxwind_kph': 15.1,
#     'totalprecip_mm': 10.5,
#     'totalprecip_in': 0.41,
#     'avgvis_km': 9.1,
#     'avgvis_miles': 5.0,
#     'avghumidity': 72.0,
#     'daily_will_it_rain': 1,
#     'daily_chance_of_rain': '88',
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': '0',
#     'condition': {'text': 'Moderate rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#      'code': 1189},
#     'uv': 8.0},
#    'astro': {'sunrise': '06:35 AM',
#     'sunset': '06:26 PM',
#     'moonrise': '12:14 AM',
#     'moonset': '01:01 PM',
#     'moon_phase': 'Waning Crescent',
#     'moon_illumination': '41'},
#    'hour': [{'time_epoch': 1604790000,
#      'time': '2020-11-08 00:00',
#      'temp_c': 27.8,
#      'temp_f': 82.0,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 218,
#      'wind_dir': 'SW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 77,
#      'cloud': 36,
#      'feelslike_c': 31.3,
#      'feelslike_f': 88.3,
#      'windchill_c': 27.8,
#      'windchill_f': 82.0,
#      'heatindex_c': 31.3,
#      'heatindex_f': 88.3,
#      'dewpoint_c': 23.3,
#      'dewpoint_f': 73.9,
#      'will_it_rain': 0,
#      'chance_of_rain': '0',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.4,
#      'gust_kph': 21.6},
#     {'time_epoch': 1604793600,
#      'time': '2020-11-08 01:00',
#      'temp_c': 27.6,
#      'temp_f': 81.7,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 220,
#      'wind_dir': 'SW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 78,
#      'cloud': 46,
#      'feelslike_c': 31.1,
#      'feelslike_f': 88.0,
#      'windchill_c': 27.6,
#      'windchill_f': 81.7,
#      'heatindex_c': 31.1,
#      'heatindex_f': 88.0,
#      'dewpoint_c': 23.4,
#      'dewpoint_f': 74.1,
#      'will_it_rain': 0,
#      'chance_of_rain': '0',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.3,
#      'gust_kph': 19.8},
#     {'time_epoch': 1604797200,
#      'time': '2020-11-08 02:00',
#      'temp_c': 27.5,
#      'temp_f': 81.5,
#      'is_day': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#       'code': 1063},
#      'wind_mph': 8.3,
#      'wind_kph': 13.3,
#      'wind_degree': 228,
#      'wind_dir': 'SW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.3,
#      'precip_in': 0.01,
#      'humidity': 78,
#      'cloud': 59,
#      'feelslike_c': 30.9,
#      'feelslike_f': 87.6,
#      'windchill_c': 27.5,
#      'windchill_f': 81.5,
#      'heatindex_c': 30.9,
#      'heatindex_f': 87.6,
#      'dewpoint_c': 23.3,
#      'dewpoint_f': 73.9,
#      'will_it_rain': 0,
#      'chance_of_rain': '24',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.7,
#      'vis_miles': 6.0,
#      'gust_mph': 11.9,
#      'gust_kph': 19.1},
#     {'time_epoch': 1604800800,
#      'time': '2020-11-08 03:00',
#      'temp_c': 27.4,
#      'temp_f': 81.3,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.1,
#      'wind_kph': 13.0,
#      'wind_degree': 237,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.5,
#      'precip_in': 0.02,
#      'humidity': 78,
#      'cloud': 72,
#      'feelslike_c': 30.8,
#      'feelslike_f': 87.4,
#      'windchill_c': 27.4,
#      'windchill_f': 81.3,
#      'heatindex_c': 30.8,
#      'heatindex_f': 87.4,
#      'dewpoint_c': 23.2,
#      'dewpoint_f': 73.8,
#      'will_it_rain': 0,
#      'chance_of_rain': '47',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.3,
#      'vis_miles': 5.0,
#      'gust_mph': 11.2,
#      'gust_kph': 18.0},
#     {'time_epoch': 1604804400,
#      'time': '2020-11-08 04:00',
#      'temp_c': 27.3,
#      'temp_f': 81.1,
#      'is_day': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#       'code': 1063},
#      'wind_mph': 7.8,
#      'wind_kph': 12.6,
#      'wind_degree': 246,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.3,
#      'precip_mm': 0.8,
#      'precip_in': 0.03,
#      'humidity': 78,
#      'cloud': 85,
#      'feelslike_c': 30.6,
#      'feelslike_f': 87.1,
#      'windchill_c': 27.3,
#      'windchill_f': 81.1,
#      'heatindex_c': 30.6,
#      'heatindex_f': 87.1,
#      'dewpoint_c': 23.1,
#      'dewpoint_f': 73.6,
#      'will_it_rain': 1,
#      'chance_of_rain': '71',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 10.7,
#      'gust_kph': 17.3},
#     {'time_epoch': 1604808000,
#      'time': '2020-11-08 05:00',
#      'temp_c': 27.1,
#      'temp_f': 80.8,
#      'is_day': 0,
#      'condition': {'text': 'Light rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#       'code': 1240},
#      'wind_mph': 7.6,
#      'wind_kph': 12.2,
#      'wind_degree': 248,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.8,
#      'precip_in': 0.03,
#      'humidity': 79,
#      'cloud': 82,
#      'feelslike_c': 30.4,
#      'feelslike_f': 86.7,
#      'windchill_c': 27.1,
#      'windchill_f': 80.8,
#      'heatindex_c': 30.4,
#      'heatindex_f': 86.7,
#      'dewpoint_c': 23.1,
#      'dewpoint_f': 73.6,
#      'will_it_rain': 1,
#      'chance_of_rain': '75',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.3,
#      'vis_miles': 5.0,
#      'gust_mph': 10.5,
#      'gust_kph': 16.9},
#     {'time_epoch': 1604811600,
#      'time': '2020-11-08 06:00',
#      'temp_c': 27.0,
#      'temp_f': 80.6,
#      'is_day': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#       'code': 1063},
#      'wind_mph': 7.2,
#      'wind_kph': 11.5,
#      'wind_degree': 250,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.8,
#      'precip_in': 0.03,
#      'humidity': 79,
#      'cloud': 79,
#      'feelslike_c': 30.1,
#      'feelslike_f': 86.2,
#      'windchill_c': 27.0,
#      'windchill_f': 80.6,
#      'heatindex_c': 30.1,
#      'heatindex_f': 86.2,
#      'dewpoint_c': 23.0,
#      'dewpoint_f': 73.4,
#      'will_it_rain': 1,
#      'chance_of_rain': '78',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.7,
#      'vis_miles': 6.0,
#      'gust_mph': 10.1,
#      'gust_kph': 16.2},
#     {'time_epoch': 1604815200,
#      'time': '2020-11-08 07:00',
#      'temp_c': 26.8,
#      'temp_f': 80.2,
#      'is_day': 1,
#      'condition': {'text': 'Light rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#       'code': 1240},
#      'wind_mph': 6.9,
#      'wind_kph': 11.2,
#      'wind_degree': 253,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.8,
#      'precip_in': 0.03,
#      'humidity': 80,
#      'cloud': 77,
#      'feelslike_c': 29.9,
#      'feelslike_f': 85.8,
#      'windchill_c': 26.8,
#      'windchill_f': 80.2,
#      'heatindex_c': 29.9,
#      'heatindex_f': 85.8,
#      'dewpoint_c': 23.0,
#      'dewpoint_f': 73.4,
#      'will_it_rain': 1,
#      'chance_of_rain': '82',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 9.8,
#      'gust_kph': 15.8},
#     {'time_epoch': 1604818800,
#      'time': '2020-11-08 08:00',
#      'temp_c': 27.7,
#      'temp_f': 81.9,
#      'is_day': 1,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'wind_mph': 7.2,
#      'wind_kph': 11.5,
#      'wind_degree': 253,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.5,
#      'precip_in': 0.02,
#      'humidity': 76,
#      'cloud': 63,
#      'feelslike_c': 31.0,
#      'feelslike_f': 87.8,
#      'windchill_c': 27.7,
#      'windchill_f': 81.9,
#      'heatindex_c': 31.0,
#      'heatindex_f': 87.8,
#      'dewpoint_c': 23.0,
#      'dewpoint_f': 73.4,
#      'will_it_rain': 0,
#      'chance_of_rain': '55',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 9.4,
#      'gust_kph': 15.1},
#     {'time_epoch': 1604822400,
#      'time': '2020-11-08 09:00',
#      'temp_c': 28.5,
#      'temp_f': 83.3,
#      'is_day': 1,
#      'condition': {'text': 'Light rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#       'code': 1240},
#      'wind_mph': 7.2,
#      'wind_kph': 11.5,
#      'wind_degree': 254,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.3,
#      'precip_in': 0.01,
#      'humidity': 72,
#      'cloud': 48,
#      'feelslike_c': 32.2,
#      'feelslike_f': 90.0,
#      'windchill_c': 28.5,
#      'windchill_f': 83.3,
#      'heatindex_c': 32.2,
#      'heatindex_f': 90.0,
#      'dewpoint_c': 22.9,
#      'dewpoint_f': 73.2,
#      'will_it_rain': 0,
#      'chance_of_rain': '27',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.9,
#      'gust_kph': 14.4},
#     {'time_epoch': 1604826000,
#      'time': '2020-11-08 10:00',
#      'temp_c': 29.4,
#      'temp_f': 84.9,
#      'is_day': 1,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'wind_mph': 7.4,
#      'wind_kph': 11.9,
#      'wind_degree': 255,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1015.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 68,
#      'cloud': 34,
#      'feelslike_c': 33.3,
#      'feelslike_f': 91.9,
#      'windchill_c': 29.4,
#      'windchill_f': 84.9,
#      'heatindex_c': 33.3,
#      'heatindex_f': 91.9,
#      'dewpoint_c': 22.9,
#      'dewpoint_f': 73.2,
#      'will_it_rain': 0,
#      'chance_of_rain': '0',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.5,
#      'gust_kph': 13.7},
#     {'time_epoch': 1604829600,
#      'time': '2020-11-08 11:00',
#      'temp_c': 29.7,
#      'temp_f': 85.5,
#      'is_day': 1,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'wind_mph': 7.6,
#      'wind_kph': 12.2,
#      'wind_degree': 254,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 67,
#      'cloud': 51,
#      'feelslike_c': 33.6,
#      'feelslike_f': 92.5,
#      'windchill_c': 29.7,
#      'windchill_f': 85.5,
#      'heatindex_c': 33.6,
#      'heatindex_f': 92.5,
#      'dewpoint_c': 22.8,
#      'dewpoint_f': 73.0,
#      'will_it_rain': 0,
#      'chance_of_rain': '25',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.7,
#      'gust_kph': 14.0},
#     {'time_epoch': 1604833200,
#      'time': '2020-11-08 12:00',
#      'temp_c': 29.9,
#      'temp_f': 85.8,
#      'is_day': 1,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'wind_mph': 7.6,
#      'wind_kph': 12.2,
#      'wind_degree': 252,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.1,
#      'precip_in': 0.0,
#      'humidity': 65,
#      'cloud': 68,
#      'feelslike_c': 33.8,
#      'feelslike_f': 92.8,
#      'windchill_c': 29.9,
#      'windchill_f': 85.8,
#      'heatindex_c': 33.8,
#      'heatindex_f': 92.8,
#      'dewpoint_c': 22.6,
#      'dewpoint_f': 72.7,
#      'will_it_rain': 0,
#      'chance_of_rain': '49',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.7,
#      'gust_kph': 14.0},
#     {'time_epoch': 1604836800,
#      'time': '2020-11-08 13:00',
#      'temp_c': 30.2,
#      'temp_f': 86.4,
#      'is_day': 1,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'wind_mph': 7.8,
#      'wind_kph': 12.6,
#      'wind_degree': 251,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.1,
#      'precip_in': 0.0,
#      'humidity': 63,
#      'cloud': 85,
#      'feelslike_c': 34.1,
#      'feelslike_f': 93.4,
#      'windchill_c': 30.2,
#      'windchill_f': 86.4,
#      'heatindex_c': 34.1,
#      'heatindex_f': 93.4,
#      'dewpoint_c': 22.5,
#      'dewpoint_f': 72.5,
#      'will_it_rain': 1,
#      'chance_of_rain': '74',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.9,
#      'gust_kph': 14.4},
#     {'time_epoch': 1604840400,
#      'time': '2020-11-08 14:00',
#      'temp_c': 30.3,
#      'temp_f': 86.5,
#      'is_day': 1,
#      'condition': {'text': 'Moderate or heavy rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#       'code': 1243},
#      'wind_mph': 7.6,
#      'wind_kph': 12.2,
#      'wind_degree': 244,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.4,
#      'precip_mm': 1.1,
#      'precip_in': 0.04,
#      'humidity': 64,
#      'cloud': 81,
#      'feelslike_c': 34.3,
#      'feelslike_f': 93.7,
#      'windchill_c': 30.3,
#      'windchill_f': 86.5,
#      'heatindex_c': 34.3,
#      'heatindex_f': 93.7,
#      'dewpoint_c': 22.6,
#      'dewpoint_f': 72.7,
#      'will_it_rain': 1,
#      'chance_of_rain': '74',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 10.1,
#      'gust_kph': 16.2},
#     {'time_epoch': 1604844000,
#      'time': '2020-11-08 15:00',
#      'temp_c': 30.3,
#      'temp_f': 86.5,
#      'is_day': 1,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'wind_mph': 7.6,
#      'wind_kph': 12.2,
#      'wind_degree': 237,
#      'wind_dir': 'WSW',
#      'pressure_mb': 1011.0,
#      'pressure_in': 30.3,
#      'precip_mm': 2.2,
#      'precip_in': 0.09,
#      'humidity': 64,
#      'cloud': 78,
#      'feelslike_c': 34.4,
#      'feelslike_f': 93.9,
#      'windchill_c': 30.3,
#      'windchill_f': 86.5,
#      'heatindex_c': 34.4,
#      'heatindex_f': 93.9,
#      'dewpoint_c': 22.6,
#      'dewpoint_f': 72.7,
#      'will_it_rain': 1,
#      'chance_of_rain': '74',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 8.0,
#      'vis_miles': 4.0,
#      'gust_mph': 11.2,
#      'gust_kph': 18.0},
#     {'time_epoch': 1604847600,
#      'time': '2020-11-08 16:00',
#      'temp_c': 30.4,
#      'temp_f': 86.7,
#      'is_day': 1,
#      'condition': {'text': 'Moderate or heavy rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#       'code': 1243},
#      'wind_mph': 7.4,
#      'wind_kph': 11.9,
#      'wind_degree': 230,
#      'wind_dir': 'SW',
#      'pressure_mb': 1010.0,
#      'pressure_in': 30.3,
#      'precip_mm': 3.2,
#      'precip_in': 0.13,
#      'humidity': 64,
#      'cloud': 74,
#      'feelslike_c': 34.6,
#      'feelslike_f': 94.3,
#      'windchill_c': 30.4,
#      'windchill_f': 86.7,
#      'heatindex_c': 34.6,
#      'heatindex_f': 94.3,
#      'dewpoint_c': 22.7,
#      'dewpoint_f': 72.9,
#      'will_it_rain': 1,
#      'chance_of_rain': '74',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 7.0,
#      'vis_miles': 4.0,
#      'gust_mph': 12.3,
#      'gust_kph': 19.8},
#     {'time_epoch': 1604851200,
#      'time': '2020-11-08 17:00',
#      'temp_c': 29.7,
#      'temp_f': 85.5,
#      'is_day': 1,
#      'condition': {'text': 'Moderate or heavy rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#       'code': 1243},
#      'wind_mph': 7.8,
#      'wind_kph': 12.6,
#      'wind_degree': 226,
#      'wind_dir': 'SW',
#      'pressure_mb': 1011.0,
#      'pressure_in': 30.3,
#      'precip_mm': 4.0,
#      'precip_in': 0.16,
#      'humidity': 66,
#      'cloud': 76,
#      'feelslike_c': 33.7,
#      'feelslike_f': 92.7,
#      'windchill_c': 29.7,
#      'windchill_f': 85.5,
#      'heatindex_c': 33.7,
#      'heatindex_f': 92.7,
#      'dewpoint_c': 22.8,
#      'dewpoint_f': 73.0,
#      'will_it_rain': 1,
#      'chance_of_rain': '79',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 7.0,
#      'vis_miles': 4.0,
#      'gust_mph': 13.6,
#      'gust_kph': 22.0},
#     {'time_epoch': 1604854800,
#      'time': '2020-11-08 18:00',
#      'temp_c': 29.1,
#      'temp_f': 84.4,
#      'is_day': 1,
#      'condition': {'text': 'Moderate or heavy rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#       'code': 1243},
#      'wind_mph': 8.1,
#      'wind_kph': 13.0,
#      'wind_degree': 222,
#      'wind_dir': 'SW',
#      'pressure_mb': 1011.0,
#      'pressure_in': 30.3,
#      'precip_mm': 4.8,
#      'precip_in': 0.19,
#      'humidity': 69,
#      'cloud': 77,
#      'feelslike_c': 32.8,
#      'feelslike_f': 91.0,
#      'windchill_c': 29.1,
#      'windchill_f': 84.4,
#      'heatindex_c': 32.8,
#      'heatindex_f': 91.0,
#      'dewpoint_c': 22.8,
#      'dewpoint_f': 73.0,
#      'will_it_rain': 1,
#      'chance_of_rain': '83',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 7.0,
#      'vis_miles': 4.0,
#      'gust_mph': 14.8,
#      'gust_kph': 23.8},
#     {'time_epoch': 1604858400,
#      'time': '2020-11-08 19:00',
#      'temp_c': 28.4,
#      'temp_f': 83.1,
#      'is_day': 0,
#      'condition': {'text': 'Moderate or heavy rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#       'code': 1243},
#      'wind_mph': 8.5,
#      'wind_kph': 13.7,
#      'wind_degree': 218,
#      'wind_dir': 'SW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.4,
#      'precip_mm': 5.6,
#      'precip_in': 0.22,
#      'humidity': 72,
#      'cloud': 79,
#      'feelslike_c': 31.9,
#      'feelslike_f': 89.4,
#      'windchill_c': 28.4,
#      'windchill_f': 83.1,
#      'heatindex_c': 31.9,
#      'heatindex_f': 89.4,
#      'dewpoint_c': 22.9,
#      'dewpoint_f': 73.2,
#      'will_it_rain': 1,
#      'chance_of_rain': '88',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 7.0,
#      'vis_miles': 4.0,
#      'gust_mph': 16.1,
#      'gust_kph': 25.9},
#     {'time_epoch': 1604862000,
#      'time': '2020-11-08 20:00',
#      'temp_c': 28.2,
#      'temp_f': 82.8,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.7,
#      'wind_kph': 14.0,
#      'wind_degree': 209,
#      'wind_dir': 'SSW',
#      'pressure_mb': 1012.0,
#      'pressure_in': 30.4,
#      'precip_mm': 3.7,
#      'precip_in': 0.15,
#      'humidity': 73,
#      'cloud': 61,
#      'feelslike_c': 31.6,
#      'feelslike_f': 88.9,
#      'windchill_c': 28.2,
#      'windchill_f': 82.8,
#      'heatindex_c': 31.6,
#      'heatindex_f': 88.9,
#      'dewpoint_c': 22.8,
#      'dewpoint_f': 73.0,
#      'will_it_rain': 0,
#      'chance_of_rain': '59',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 8.0,
#      'vis_miles': 4.0,
#      'gust_mph': 15.2,
#      'gust_kph': 24.5},
#     {'time_epoch': 1604865600,
#      'time': '2020-11-08 21:00',
#      'temp_c': 28.0,
#      'temp_f': 82.4,
#      'is_day': 0,
#      'condition': {'text': 'Moderate or heavy rain shower',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#       'code': 1243},
#      'wind_mph': 9.2,
#      'wind_kph': 14.8,
#      'wind_degree': 201,
#      'wind_dir': 'SSW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 1.9,
#      'precip_in': 0.07,
#      'humidity': 73,
#      'cloud': 42,
#      'feelslike_c': 31.3,
#      'feelslike_f': 88.3,
#      'windchill_c': 28.0,
#      'windchill_f': 82.4,
#      'heatindex_c': 31.3,
#      'heatindex_f': 88.3,
#      'dewpoint_c': 22.8,
#      'dewpoint_f': 73.0,
#      'will_it_rain': 0,
#      'chance_of_rain': '29',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 14.5,
#      'gust_kph': 23.4},
#     {'time_epoch': 1604869200,
#      'time': '2020-11-08 22:00',
#      'temp_c': 27.8,
#      'temp_f': 82.0,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 9.4,
#      'wind_kph': 15.1,
#      'wind_degree': 192,
#      'wind_dir': 'SSW',
#      'pressure_mb': 1014.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 74,
#      'cloud': 24,
#      'feelslike_c': 31.0,
#      'feelslike_f': 87.8,
#      'windchill_c': 27.8,
#      'windchill_f': 82.0,
#      'heatindex_c': 31.0,
#      'heatindex_f': 87.8,
#      'dewpoint_c': 22.7,
#      'dewpoint_f': 72.9,
#      'will_it_rain': 0,
#      'chance_of_rain': '0',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 13.6,
#      'gust_kph': 22.0},
#     {'time_epoch': 1604872800,
#      'time': '2020-11-08 23:00',
#      'temp_c': 27.7,
#      'temp_f': 81.9,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 8.7,
#      'wind_kph': 14.0,
#      'wind_degree': 193,
#      'wind_dir': 'SSW',
#      'pressure_mb': 1013.0,
#      'pressure_in': 30.4,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 73,
#      'cloud': 29,
#      'feelslike_c': 30.8,
#      'feelslike_f': 87.4,
#      'windchill_c': 27.7,
#      'windchill_f': 81.9,
#      'heatindex_c': 30.8,
#      'heatindex_f': 87.4,
#      'dewpoint_c': 22.5,
#      'dewpoint_f': 72.5,
#      'will_it_rain': 0,
#      'chance_of_rain': '0',
#      'will_it_snow': 0,
#      'chance_of_snow': '0',
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 12.5,
#      'gust_kph': 20.2}]}]}

# %%
print(day)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-b0c2a59a717b> in <module>
# ----> 1 print(day)
#
# NameError: name 'day' is not defined

# %%
# print(forecast.index)

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %%
# Rename data variable

# %%
# Data = Temp

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
url = "http://api.weatherapi.com/v1/forecast.json?key=ea62b294238944a09bd05542200411&q=Lagos&days=7"

# %%
response = requests.get('http://api.weatherapi.com/v1/forecast.json?key=ea62b294238944a09bd05542200411&q=Lagos&days=7')
week_forecast = response.json()

# %%
# {
#     maxtemp_c
# if maxtemp_c > 30,
#    print("HOT DAY")
# elif maxtemp = 30,
#    print("WARM DAY")
# else 
#    print ("COLD DAY")
# }

# %%
#UNFINISHED

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?

# %%
print()

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2015? How about 2012? 2007? How far back does the API allow you to go?
#
# - *Tip: You'll need to use latitude/longitude. You can ask Google, it knows*
# - *Tip: Remember when latitude/longitude might use negative numbers*
