# %%
import pandas as pd

# %%
# !head -n 5 countries.csv
# Out:
# country,continent,gdp_per_capita,life_expectancy,population
# Afghanistan,Asia,663,54.863,22856302
# Albania,Europe,4195,74.2,3071856
# Algeria,Africa,5098,68.96300000000001,30533827
# Angola,Africa,2446,45.233999999999995,13926373

# %%
# Open a CSV file using pandas
# dataframe
df = pd.read_csv("countries.csv")

df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.tail()
# Out:
#                 country continent  gdp_per_capita  life_expectancy  population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.head(10)
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
# 5            Argentina  S. America           10571           73.822
# 6              Armenia      Europe            2114           71.494
# 7            Australia     Oceania           29241           79.930
# 8              Austria      Europe           32008           78.330
# 9           Azerbaijan      Europe            2533           66.851
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656
# 5    36930709
# 6     3076098
# 7    19164351
# 8     8004712
# 9     8110723

# %%
df.tail(15)
# Out:
#                   country   continent  gdp_per_capita  life_expectancy  \
# 173          Turkmenistan        Asia            3289           63.925
# 174                Uganda      Africa             881           48.126
# 175               Ukraine      Europe            3700           67.790
# 176  United Arab Emirates        Asia           30012           74.163
# 177        United Kingdom      Europe           28644           78.040
# 178         United States  N. America           39758           76.800
# 179               Uruguay  S. America            9092           74.777
# 180            Uzbekistan        Asia            1635           66.999
# 181               Vanuatu     Oceania            3762           67.438
# 182             Venezuela  S. America            9434           72.432
# 183               Vietnam        Asia            1577           73.777
# 184    West Bank and Gaza        Asia            7586           70.929
# ...

# %%
df.columns
# Out:
# Index(['country', 'continent', 'gdp_per_capita', 'life_expectancy',
#        'population'],
#       dtype='object')

# %%
# Regional distribution
# lowest/highest life expectancies
# life expectancies in richest vs poorest
# rank largest population
# countries w low FDP and low life expectancy
# total GDP (gdp_per_capita * population)
# world average life expectancy
# life expectancy by continent
# correlation between GDP and life expectancy

# %%
df['population']
# Out:
# 0      22856302
# 1       3071856
# 2      30533827
# 3      13926373
# 4         77656
#          ...
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477
# Name: population, Length: 188, dtype: int64

# %%
df.population
# Out:
# 0      22856302
# 1       3071856
# 2      30533827
# 3      13926373
# 4         77656
#          ...
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477
# Name: population, Length: 188, dtype: int64

# %%
df.population.sum()
# Out:
# 6115042358

# %%
df.population.mean()
# Out:
# 32526821.05319149

# %%
df.population.median()
# Out:
# 6888970.5

# %%
df.population.max()
# Out:
# 1269116737

# %%
df.sort_values(by='population')
# Out:
#                  country   continent  gdp_per_capita  life_expectancy  \
# 64             Greenland  N. America           33204           67.030
# 4    Antigua and Barbuda  N. America           12738           73.544
# 146           Seychelles      Africa           15230           71.771
# 87              Kiribati     Oceania            3501           64.642
# 169                Tonga     Oceania            4886           70.810
# ..                   ...         ...             ...              ...
# 22                Brazil  S. America            8056           70.261
# 76             Indonesia        Asia            2714           67.289
# 178        United States  N. America           39758           76.800
# 75                 India        Asia            1648           62.129
# 34                 China        Asia            3407           72.124
#
#      population
# 64        56196
# 4         77656
# 146       78685
# 87        84010
# 169       97935
# ..          ...
# ...

# %%
# Top 10 countries by population
df.sort_values(by='population', ascending=False).head(10)
# Out:
#            country   continent  gdp_per_capita  life_expectancy  population
# 34           China        Asia            3407           72.124  1269116737
# 75           India        Asia            1648           62.129  1053898107
# 178  United States  N. America           39758           76.800   282496310
# 76       Indonesia        Asia            2714           67.289   213395411
# 22          Brazil  S. America            8056           70.261   174425387
# 137         Russia        Asia            8570           65.380   146757517
# 127       Pakistan        Asia            2086           63.854   144522192
# 12      Bangladesh        Asia            1075           65.309   129592275
# 83           Japan        Asia           28559           81.350   125720310
# 124        Nigeria      Africa            1619           46.629   123688536

# %%
df.life_expectancy.median()
# Out:
# 70.04150000000001

# %%
df.life_expectancy.max()
# Out:
# 81.35

# %%
df.life_expectancy.min()
# Out:
# 38.12300000000001

# %%
df.life_expectancy.describe()
# Out:
# count    188.000000
# mean      66.501536
# std       10.298458
# min       38.123000
# 25%       59.663750
# 50%       70.041500
# 75%       74.134500
# max       81.350000
# Name: life_expectancy, dtype: float64

# %%
df.population.describe()
# Out:
# count    1.880000e+02
# mean     3.252682e+07
# std      1.237952e+08
# min      5.619600e+04
# 25%      2.003170e+06
# 50%      6.888970e+06
# 75%      2.218517e+07
# max      1.269117e+09
# Name: population, dtype: float64

# %%
df.describe()
# Out:
#        gdp_per_capita  life_expectancy    population
# count      188.000000       188.000000  1.880000e+02
# mean      9977.558511        66.501536  3.252682e+07
# std      11953.393378        10.298458  1.237952e+08
# min        292.000000        38.123000  5.619600e+04
# 25%       1732.500000        59.663750  2.003170e+06
# 50%       5290.500000        70.041500  6.888970e+06
# 75%      12701.250000        74.134500  2.218517e+07
# max      63924.000000        81.350000  1.269117e+09

# %%
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.continent.describe()
# Out:
# count        188
# unique         6
# top       Africa
# freq          54
# Name: continent, dtype: object

# %%
df.continent.value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: continent, dtype: int64

# %%
df.continent.value_counts(normalize=True)
# Out:
# Africa        0.287234
# Asia          0.255319
# Europe        0.223404
# N. America    0.117021
# S. America    0.063830
# Oceania       0.053191
# Name: continent, dtype: float64

# %%
df.continent.value_counts(normalize=True) * 100
# Out:
# Africa        28.723404
# Asia          25.531915
# Europe        22.340426
# N. America    11.702128
# S. America     6.382979
# Oceania        5.319149
# Name: continent, dtype: float64

# %%
df.population / 1000000
# Out:
# 0      22.856302
# 1       3.071856
# 2      30.533827
# 3      13.926373
# 4       0.077656
#          ...
# 183    78.758010
# 184     3.198560
# 185    17.723186
# 186    10.201562
# 187    12.509477
# Name: population, Length: 188, dtype: float64

# %%
df.groupby('continent').life_expectancy.mean()
# Out:
# continent
# Africa        54.067713
# Asia          69.257187
# Europe        74.994602
# N. America    71.529318
# Oceania       68.747400
# S. America    70.616250
# Name: life_expectancy, dtype: float64

# %%
df.groupby('continent').life_expectancy.mean().sort_values()
# Out:
# continent
# Africa        54.067713
# Oceania       68.747400
# Asia          69.257187
# S. America    70.616250
# N. America    71.529318
# Europe        74.994602
# Name: life_expectancy, dtype: float64

# %%
df.groupby('continent').life_expectancy.mean().sort_index()
# Out:
# continent
# Africa        54.067713
# Asia          69.257187
# Europe        74.994602
# N. America    71.529318
# Oceania       68.747400
# S. America    70.616250
# Name: life_expectancy, dtype: float64

# %%
df.groupby('continent').life_expectancy.mean().sort_values(ascending=False)
# Out:
# continent
# Europe        74.994602
# N. America    71.529318
# S. America    70.616250
# Asia          69.257187
# Oceania       68.747400
# Africa        54.067713
# Name: life_expectancy, dtype: float64

# %%
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.gdp_per_capita * df.population
# Out:
# 0       15153728226
# 1       12886435920
# 2      155661450046
# 3       34063908358
# 4         989182128
#            ...
# 183    124201381770
# 184     24264276160
# 185     39292303362
# 186     10558616670
# 187      9319560365
# Length: 188, dtype: int64

# %%
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df['gdp'] = df.gdp_per_capita * df.population
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population           gdp
# 0    22856302   15153728226
# 1     3071856   12886435920
# 2    30533827  155661450046
# 3    13926373   34063908358
# 4       77656     989182128

# %%
# Save a new copy with all of our new columns
df.to_csv("countries-with-gdp.csv", index=False)

# %%
df.continent
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
#           ...
# 183          Asia
# 184          Asia
# 185          Asia
# 186        Africa
# 187        Africa
# Name: continent, Length: 188, dtype: object

# %%
df.continent == "Asia"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 183     True
# 184     True
# 185     True
# 186    False
# 187    False
# Name: continent, Length: 188, dtype: bool

# %%
df[df.continent == "Asia"]
# Out:
#                   country continent  gdp_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 11                Bahrain      Asia           22015           74.497
# 12             Bangladesh      Asia            1075           65.309
# 18                 Bhutan      Asia            2922           60.307
# 23                 Brunei      Asia           48020           75.927
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# ...

# %%
df[df.country == "Singapore"]
# Out:
#        country continent  gdp_per_capita  life_expectancy  population  \
# 148  Singapore      Asia           36834            78.34     3919300
#
#               gdp
# 148  144363496200

# %%
# Get Asian countries with a pop > a million
df[(df.continent == "Asia") & (df.population > 1000000)]
# Out:
#                   country continent  gdp_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 12             Bangladesh      Asia            1075           65.309
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# 83                  Japan      Asia           28559           81.350
# 84                 Jordan      Asia            3664           71.724
# 85             Kazakhstan      Asia            5366           63.513
# ...

# %%
# Out of all the countries in Africa with a population over a million
# Get the top 5 in life expectancy
df[(df.continent == "Africa") & (df.population > 1000000)].sort_values(by='life_expectancy', ascending=False).head(5)
# Out:
#        country continent  gdp_per_capita  life_expectancy  population  \
# 171    Tunisia    Africa            5480           73.159     9456117
# 97       Libya    Africa            9139           71.872     5231189
# 109  Mauritius    Africa            8290           71.202     1196027
# 2      Algeria    Africa            5098           68.963    30533827
# 49       Egypt    Africa            4629           68.632    67648419
#
#               gdp
# 171   51819521160
# 97    47807836271
# 109    9915063830
# 2    155661450046
# 49   313144531551

# %%
df[(df.continent == "Africa") & (df.population > 1000000)] \
    .sort_values(by='life_expectancy', ascending=False) \
    .head(5)
# Out:
#        country continent  gdp_per_capita  life_expectancy  population  \
# 171    Tunisia    Africa            5480           73.159     9456117
# 97       Libya    Africa            9139           71.872     5231189
# 109  Mauritius    Africa            8290           71.202     1196027
# 2      Algeria    Africa            5098           68.963    30533827
# 49       Egypt    Africa            4629           68.632    67648419
#
#               gdp
# 171   51819521160
# 97    47807836271
# 109    9915063830
# 2    155661450046
# 49   313144531551

# %%
df[
    (df.continent == "Africa") & (df.population > 1000000)
].sort_values(
    by='life_expectancy',
    ascending=False
).head(5)
# Out:
#        country continent  gdp_per_capita  life_expectancy  population  \
# 171    Tunisia    Africa            5480           73.159     9456117
# 97       Libya    Africa            9139           71.872     5231189
# 109  Mauritius    Africa            8290           71.202     1196027
# 2      Algeria    Africa            5098           68.963    30533827
# 49       Egypt    Africa            4629           68.632    67648419
#
#               gdp
# 171   51819521160
# 97    47807836271
# 109    9915063830
# 2    155661450046
# 49   313144531551

# %%
df[
    (df.continent == "Africa") & (df.population > 1000000)
].sort_values(
    by='life_expectancy',
    ascending=False
).head(5)
# Out:
#        country continent  gdp_per_capita  life_expectancy  population  \
# 171    Tunisia    Africa            5480           73.159     9456117
# 97       Libya    Africa            9139           71.872     5231189
# 109  Mauritius    Africa            8290           71.202     1196027
# 2      Algeria    Africa            5098           68.963    30533827
# 49       Egypt    Africa            4629           68.632    67648419
#
#               gdp
# 171   51819521160
# 97    47807836271
# 109    9915063830
# 2    155661450046
# 49   313144531551

# %%
df.population.plot()

# %%
df.plot(x='country', y='population')

# %%
df.plot(x='country', y='population', figsize=(10, 5))

# %%
df.plot(x='country', y='population', figsize=(10, 5), kind='bar')

# %%
df.plot(x='country', y='population', figsize=(10, 5), kind='barh')

# %%
# Make the graph the right size so we can see every country
# Make it go from big countries up top to little countries at the bottom
df.sort_values(by='population') \
    .plot(
        x='country',
        y='population',
        figsize=(5, 35),
        kind='barh'
    )

# %%
df.population.hist()

# %%
df.population.hist(bins=100)

# %%
df.groupby('continent').gdp_per_capita.median().sort_values().plot(kind='barh')

# %%
# Make the graph the right size so we can see every country
# Make it go from big countries up top to little countries at the bottom
df.sort_values(by=['population', 'gdp_per_capita']) \
    .plot(
        x='country',
        y='population',
        figsize=(5, 35),
        kind='barh'
    )

# %%
import psycopg2

conn_string = f"host=127.0.0.1 port=5432 dbname=mondial password= user="
conn=psycopg2.connect(conn_string)
df = pd.read_sql("SELECT * FROM city LIMIT 100", conn)
df.head()
# Out:
#       name country province  population  latitude  longitude  elevation
# 0   Tirana      AL  Albania    418495.0     41.33      19.82      110.0
# 1  Shkodër      AL  Albania     77075.0     42.07      19.50       13.0
# 2   Durrës      AL  Albania    113249.0     41.32      19.45       40.0
# 3    Vlorë      AL  Albania     79513.0     40.47      19.49       25.0
# 4  Elbasan      AL  Albania     78703.0     41.10      20.07      150.0

# %%
df = pd.read_csv("school-shootings-data.csv")
df.head()
# Out:
#    uid nces_school_id                  school_name  nces_district_id  \
# 0    1   080480000707        Columbine High School          804800.0
# 1    2   220054000422  Scotlandville Middle School         2200540.0
# 2    3   130441001591         Heritage High School         1304410.0
# 3    4   421899003847     John Bartram High School         4218990.0
# 4    5   250279000225       Dorchester High School         2502790.0
#
#                           district_name       date school_year  year  \
# 0                  Jefferson County R-1  4/20/1999   1998-1999  1999
# 1  East Baton Rouge Parish School Board  4/22/1999   1998-1999  1999
# 2                       Rockdale County  5/20/1999   1998-1999  1999
# 3                  Philadelphia City SD  10/4/1999   1999-2000  1999
# 4                                Boston  11/3/1999   1999-2000  1999
#
#        time day_of_week  ...        lat        long staffing low_grade  \
# ...
